# %% [markdown]
# ### Operators

# %%
# Arithmetic
a=5
b=10
# print(a+b)   #addition
# print(a-b)   #substraction
# print(a/b)    #division
# print(b//a)   #floor division
# print(a**b)    #power
# print(b%a)     #modulus

#Assignment
# a=3
# a+=5  #or a=a+5
# print(a)

# a=3
# a **=2
# print(a)

#comparison
# a=10>3
# print(a)

# a=10!=5
# b=not(a)
# print(b)

#logical operators (AND,OR,NOT)

a=True
b=False
# print(a == True and b == False)
# print(a == True or b == True)
# print(not a == True)

#Identity operators
d=4
e=9
f=9
# print(d is e)    #False
# print(e is f)    #True
# print(e is not f)  #False
# print(f is not e)   #False

#Membership operators
a=["apple","bnana","cherry"]
b="apple"
c="mango"
print(b in a)
print(c in a)
# Out:
# True
# False
