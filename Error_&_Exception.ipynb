# %% [markdown]
# ### Error & Exception

# %%
a=10/-3
print(a)


# try except else finally

try:
    a=int("abc")
except ValueError:   
    print("you cannot force string to convert into number") 
else:
    print("no error found")    
finally:
    print("this will always run")
# Out:
# -3.3333333333333335
# you cannot force string to convert into number
# this will always run

# %% [markdown]
# ### OOPs

# %%
class Car:                   #class
   def __init__(self):       #function
    self.color = "red"  
    self.tyres = 4
nexon = Car()   
print(nexon.tyres )
# Out:
# 4

# %% [markdown]
# ### Date and Time

# %%
from datetime import datetime,date,time 
livedatetime = datetime.now()
print(livedatetime)
Date = date(2026,8,13)
print(Date)
Time = time(6,35,58)
print(Time)
print(Date,Time)
# Out:
# 2026-08-13 18:36:53.673436
# 2026-08-13
# 06:35:58
# 2026-08-13 06:35:58

# %% [markdown]
# ### Comprehension

# %%
List=[]
for i in range(1,8):
    List.append(i*i)
print(List)    


name1=["raman","pihu","gyanendra","priya"]
upper_name=[i.upper() for i in name1]
print(upper_name)


# sqrNum={}
# for i in range(1,8):
#     sqrNum[i]=i*i
# print(sqrNum)    

DictComp={i:i*i for i in range(1,8)}
print(DictComp)
# Out:
# [1, 4, 9, 16, 25, 36, 49]
# ['RAMAN', 'PIHU', 'GYANENDRA', 'PRIYA']
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49}

# %% [markdown]
# ### File I/O

# %%
# file=open("intro.txt","r")
# print(file.readline())

# file2=open("intro.txt","r+")
# file2.write(" i just wanted to add this line")
# file2.close()


file2=open("intro.txt","r")
file2.seek(0)
print(file2.read())
# Out:
#  i just wanted to add this line

# %% [markdown]
# ### CSV

# %%
csvfile=open("students.csv","w")
csvfile.write("Name,Marks\n")
csvfile.write("priya,90\n")
csvfile.write("navya,77\n")

csvfile=open("students.csv","r")
print(csvfile.read())

#json
# Out:
# Name,Marks
# priya,90
# navya,77
